# %% [markdown]
# # Before diving into our analysis though, let's become familiar with the two datasets that will help you with this project:

# %% [markdown]
# # datasets/lego_sets.csv
# - set_num: A code that is unique to each set in the dataset. This column is critical, and a missing value indicates the set is a duplicate or invalid!
# - set_name: A name for every set in the dataset (note that this can be the same for different sets).
# - year: The date the set was released.
# - num_parts: The number of parts contained in the set. This column is not central to our analyses, so missing values are acceptable.
# - theme_name: The name of the sub-theme of the set.
# - parent_theme: The name of the parent theme the set belongs to. Matches the `name` column of the `parent_themes` csv file.

# %% [markdown]
# # datasets/parent_themes.csv
# - id: A code that is unique to every theme.
# - name: The name of the parent theme.
# - is_licensed: A Boolean column specifying whether the theme is a licensed theme.

# %% [markdown]
# From here on out, it will be your task to explore and manipulate the existing data until you are able to answer the two questions described in the instructions panel. Feel free to add as many cells as necessary. Finally, remember that you are only tested on your answer, not on the methods you use to arrive at the answer!

# %%
# Use this cell to begin your analyses, and add as many cells as you would like!
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/lego_sets.csv')
theme = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/parent_themes.csv')
df.head()
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
theme.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %% [markdown]
# ## What Percentage of all licensed sets ever released were Star Wars themed?

# %%
theme.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %%
df.head()
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
# Merge both dataframes together
merged_df = df.merge(theme, left_on = 'parent_theme', right_on = 'name')
merged_df.drop(columns = 'name_y', inplace = True)

# %%
merged_df.head()
# Out:
#   set_num                             name_x  year  num_parts theme_name  \
# 0    00-1                    Weetabix Castle  1970      471.0     Castle
# 1    00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2    00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3    00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4    00-7  Weetabix Promotional Lego Village  1976        NaN   Building
#
#   parent_theme   id  is_licensed
# 0     Legoland  411        False
# 1     Legoland  411        False
# 2     Legoland  411        False
# 3     Legoland  411        False
# 4     Legoland  411        False

# %%
merged_df[merged_df['set_num'].isnull()].shape
# Out:
# (153, 8)

# %%
# Filter themes that are licensed
licensed_df = merged_df[merged_df['is_licensed']]
licensed_df.dropna(subset = ['set_num'], inplace = True)
licensed_df.head()
# Out:
# /Users/adaiurieta/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       set_num                         name_x  year  num_parts  \
# 3493  10018-1                     Darth Maul  2001     1868.0
# 3494  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                     Cloud City  2003      707.0
#
#                    theme_name parent_theme   id  is_licensed
# 3493                Star Wars    Star Wars  158         True
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True
# ...

# %%
# Filter licensed parent themes that are Star Wars
star_wars = licensed_df[licensed_df['parent_theme'] == 'Star Wars']
star_wars.head(50)
# Out:
#         set_num                                    name_x  year  num_parts  \
# 3493    10018-1                                Darth Maul  2001     1868.0
# 3494    10019-1               Rebel Blockade Runner - UCS  2001        NaN
# 3495    10026-1                   Naboo Starfighter - UCS  2002        NaN
# 3496    10030-1             Imperial Star Destroyer - UCS  2002     3115.0
# 3497    10123-1                                Cloud City  2003      707.0
# 3498    10129-1                   Rebel Snowspeeder - UCS  2003     1456.0
# 3499    10131-1                    TIE Fighter Collection  2004        NaN
# 3500    10134-1           Y-wing Attack Starfighter - UCS  2004        NaN
# 3501    10143-1                             Death Star II  2005        NaN
# 3502    10144-1                               Sandcrawler  2005     1679.0
# 3503    10174-1                      Imperial AT-ST - UCS  2006        NaN
# ...

# %%
total_licensed = licensed_df[licensed_df.columns[7]].count()
starwars_licensed = star_wars[star_wars.columns[7]].count()
total_licensed
# Out:
# 1179

# %%
starwars_licensed
# Out:
# 609

# %%
the_force = int(starwars_licensed/total_licensed * 100)
print(the_force)
# Out:
# 51

# %% [markdown]
# # In which year was Star Wars not the most popular licensed theme (in terms of number of sets released that year?)
# Save your answer as a variable new_era in the the form of an integer.

# %%
licensed_df = licensed_df.sort_values('year')
licensed_df['count'] = 1
licensed_df.head()
# Out:
#      set_num            name_x  year  num_parts               theme_name  \
# 3702  7161-1        Gungan Sub  1999      379.0      Star Wars Episode 1
# 3676  7111-1     Droid Fighter  1999        NaN      Star Wars Episode 1
# 3697  7151-1  Sith Infiltrator  1999      244.0      Star Wars Episode 1
# 3671  7101-1   Lightsaber Duel  1999        NaN      Star Wars Episode 1
# 3675  7110-1       Landspeeder  1999        NaN  Star Wars Episode 4/5/6
#
#      parent_theme   id  is_licensed  count
# 3702    Star Wars  158         True      1
# 3676    Star Wars  158         True      1
# 3697    Star Wars  158         True      1
# 3671    Star Wars  158         True      1
# 3675    Star Wars  158         True      1

# %%
# count the total number of licensed and group by year and parent theme
summed_df = licensed_df.groupby(['year', 'parent_theme']).sum().reset_index()

# %%
summed_df.head()
# Out:
#    year           parent_theme  num_parts    id  is_licensed  count
# 0  1999              Star Wars     1384.0  2054           13     13
# 1  2000  Disney's Mickey Mouse      405.0  1940            5      5
# 2  2000              Star Wars     2580.0  4108           26     26
# 3  2001           Harry Potter     1284.0  2706           11     11
# 4  2001              Star Wars     2949.0  2212           14     14

# %%
max_df = summed_df.sort_values('count', ascending = False).drop_duplicates(['year'])

# %%
max_df.sort_values('year', inplace = True)
max_df.head()
# Out:
#    year parent_theme  num_parts    id  is_licensed  count
# 0  1999    Star Wars     1384.0  2054           13     13
# 2  2000    Star Wars     2580.0  4108           26     26
# 4  2001    Star Wars     2949.0  2212           14     14
# 6  2002    Star Wars     4735.0  4424           28     28
# 9  2003    Star Wars     6660.0  5056           32     32

# %%
max_df.drop(columns = ['count', 'id'], inplace = True)
max_df.head()
# Out:
#    year parent_theme  num_parts  is_licensed
# 0  1999    Star Wars     1384.0           13
# 2  2000    Star Wars     2580.0           26
# 4  2001    Star Wars     2949.0           14
# 6  2002    Star Wars     4735.0           28
# 9  2003    Star Wars     6660.0           32

# %%
max_df
# Out:
#     year  parent_theme  num_parts  is_licensed
# 0   1999     Star Wars     1384.0           13
# 2   2000     Star Wars     2580.0           26
# 4   2001     Star Wars     2949.0           14
# 6   2002     Star Wars     4735.0           28
# 9   2003     Star Wars     6660.0           32
# 12  2004     Star Wars     1659.0           20
# 16  2005     Star Wars     4730.0           28
# 20  2006     Star Wars     2769.0           11
# 24  2007     Star Wars    11361.0           16
# 28  2008     Star Wars     6865.0           23
# 32  2009     Star Wars     3953.0           39
# 36  2010     Star Wars     6003.0           30
# 42  2011     Star Wars     3451.0           32
# 47  2012     Star Wars     6769.0           43
# 52  2013     Star Wars     6159.0           35
# 59  2014     Star Wars     8293.0           45
# 67  2015     Star Wars    11410.0           58
# 76  2016     Star Wars     6934.0           61
# 82  2017  Super Heroes    13123.0           72

# %%
new_era = 2017

# %% [markdown]
# # Break down number of sets by year

# %%
clean_df = merged_df[~merged_df['set_num'].isnull()]

# %%
clean_df['count'] = 1
clean_df
# Out:
# /var/folders/8g/_8r4st493zn0yg791ddbydpc0000gn/T/ipykernel_8426/416427455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['count'] = 1
#       set_num                             name_x  year  num_parts theme_name  \
# 0        00-1                    Weetabix Castle  1970      471.0     Castle
# 1        00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2        00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3        00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4        00-7  Weetabix Promotional Lego Village  1976        NaN   Building
# ...       ...                                ...   ...        ...        ...
# ...

# %%
sets_per_year = clean_df.groupby(['year']).sum().reset_index()[['year', 'count']]

# %%
sets_per_year
# Out:
#     year  count
# 0   1950      7
# 1   1953      4
# 2   1954     14
# 3   1955     28
# 4   1956     12
# ..   ...    ...
# 61  2013    593
# 62  2014    715
# 63  2015    670
# 64  2016    608
# 65  2017    438
#
# [66 rows x 2 columns]

# %%
for index,row in sets_per_year.iterrows():
    print(row['year'], row['count'])
# Out:
# 1950 7
# 1953 4
# 1954 14
# 1955 28
# 1956 12
# 1957 21
# 1958 42
# 1959 4
# 1960 3
# 1961 17
# 1962 40
# 1963 18
# 1964 11
# 1965 10
# 1966 89
# 1967 21
# 1968 25
# 1969 69
# 1970 29
# 1971 45
# 1972 38
# 1973 68
# 1974 39
# 1975 31
# 1976 68
# 1977 92
# 1978 73
# 1979 82
# 1980 88
# 1981 79
# 1982 76
# 1983 57
# 1984 76
# 1985 139
# 1986 123
# 1987 209
# 1988 68
# 1989 114
# 1990 85
# 1991 106
# 1992 115
# 1993 111
# 1994 128
# 1995 128
# 1996 144
# 1997 194
# 1998 325
# 1999 300
# 2000 327
# 2001 339
# 2002 447
# 2003 415
# 2004 371
# 2005 330
# 2006 283
# 2007 319
# 2008 349
# 2009 403
# 2010 444
# 2011 502
# 2012 615
# 2013 593
# 2014 715
# 2015 670
# 2016 608
# 2017 438
